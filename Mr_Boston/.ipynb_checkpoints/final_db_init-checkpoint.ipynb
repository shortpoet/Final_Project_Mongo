# %%
import pandas as pd
import numpy as np

import json
import os

import re
import pymongo

from credentials_local import user, password, rds_host


from boston_functions import *
from fractions import Fraction
import re

from liquid import liquids
from garnish import garnishes
import random

# %%
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)

# %%
#import mr boston cocktail database
data = pd.read_csv("mr-boston-all-glasses.csv")
#locate data
data = data[data.loc[:, "glass-size"].notna()]

valid_units = ["oz", "tsp", "splash", "dash"]

fill_liquid = ["ginger ale", "carbonated water", "cola", "water", "chilled champagne", "soda water", 
               "club soda", "ginger ale or soda water", "lemon-lime soda", "ginger beer", "bitter lemon soda",
               "apple juice", "orange juice"]

invaild_ingredients = ['chopped', 'cut in half', 'cut in halves', 'cut into halves', 'flamed', 'hulled', 'long',
                       'skinned','whipped', "preferably b.a. reynold's", 'preferably jamaican', 'preferably japanese', 
                       'preferably pedro ximenez', "such as bittermen's elemakule", 'such as demerara', 
                       'such as islay or skye', 'such as nasturtium']

ingredient_indices = range(3, 14)

#get all recipe data
all_recipes, measures = get_cocktail_recipes(data, ingredient_indices, liquids, garnishes, invaild_ingredients, valid_units)

#set categories list
categories = list(set(data.iloc[:, 1])) + ["AI Instant Classic"]

# %%
############################
# COCKTAIL RECIPES TO TEXT #
############################
with open('mr_boston_cocktails.txt', 'w') as text_file:
    for i in range(len(all_recipies)):
        cocktail_string = all_recipies[i]['name'] + " - "
        cocktail_string += all_recipies[i]['glass'] + " - "
        for measurement, ingredient in all_recipies[i]["recipe"]:
            cocktail_string += measurement + " " + ingredient + " - "
        cocktail_string += all_recipies[i]['instructions']
        text_file.write(cocktail_string + "\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-35de68479a78> in <module>
#       3 ############################
#       4 with open('mr_boston_cocktails.txt', 'w') as text_file:
# ----> 5     for i in range(len(all_recipies)):
#       6         cocktail_string = all_recipies[i]['name'] + " - "
#       7         cocktail_string += all_recipies[i]['glass'] + " - "
#
# NameError: name 'all_recipies' is not defined

# %%
###################
# POPULATE TABLES #
###################

####################
### LIQUID TABLE ###
####################
#import colors for liquids
liquid_colors = pd.read_csv("Liquid_Colors_Final.csv")

# %%
### GLASS SVG DATA ###
#import glass svg data
svg_data = pd.read_csv("the_glasses.csv")

# %%
for recipe in all_recipes:
    if recipe['glass'] == "Beer Mug":
           recipe['glass'] = "fluted_lager"
    elif (recipe['glass'] == "Brandy Snifter") or (recipe['glass'] == "Red-Wine Glass") or (recipe['glass'] == "White-Wine Glass"):
        recipe['glass'] = "poco_grande"                                
    elif recipe['glass'] == "Champagne Flute":
        recipe['glass'] = "champagne_extra_fluted"                
    elif recipe['glass'] == "Cocktail Glass":
        recipe['glass'] = "cocktail_lg"
    elif recipe['glass'] == "Collins Glass":
        recipe['glass'] = "collins"
    elif (recipe['glass'] == "Cordial or Pony Glass") or (recipe['glass'] == "Pousse-Cafe Glass") or (recipe['glass'] == "Sherry Glass"):
        recipe['glass'] = "pousse_cafe"
    elif recipe['glass'] == "Highball Glass":
        recipe['glass'] = "highball"
    elif recipe['glass'] == "Hurricane Glass":
        recipe['glass'] = "hurricane"
    elif recipe['glass'] == "Irish Coffee Glass":
        recipe['glass'] = "irish_coffee"
    elif recipe['glass'] == "Old-Fashioned Glass":
        recipe['glass'] = "old_fashioned"
    elif (recipe['glass'] == "Punch Cup") or (recipe['glass'] == "Shot Glass"):
        recipe['glass'] = "rocks"
    elif recipe['glass'] == "Sour Glass":
        recipe['glass'] = "champagne_flute"

# %%
all_recipes[0]
# Out:
# {'name': 'Gauguin',
#  'category': 'Cocktail Classics',
#  'instructions': 'Combine ingredients with a cup of crushed ice in blender and blend at low speed. Serve in old-fashioned glass. Top with a cherry.',
#  'glass': 'old_fashioned',
#  'glass_size': 6,
#  'recipe': [['2 oz', 'batavia arrack or light rum'],
#   ['1 oz', 'passion fruit syrup'],
#   ['1 oz', 'fresh lemon juice'],
#   ['1 oz', "rose's lime juice"]]}

# %%
glasses = []
glass_dicts = []
for recipe in all_recipes:
    if recipe['glass'] not in glasses:
        this_glass = {}
        this_glass['glass_name'] = recipe['glass']
        this_glass['glass_size'] = recipe['glass_size']
        glasses.append(recipe['glass'])
        glass_dicts.append(this_glass)
glass_df = pd.DataFrame(glass_dicts)
glass_df
# Out:
#                 glass_name  glass_size
# 0   old_fashioned           6
# 1   cocktail_lg             6
# 2   collins                 14
# 3   champagne_extra_fluted  6
# 4   pousse_cafe             2
# 5   highball                7
# 6   irish_coffee            8
# 7   fluted_lager            10
# 8   champagne_flute         5
# 9   poco_grande             8
# 10  rocks                   1
# 11  hurricane               14

# %%
svg_dict = svg_data.to_dict(orient='records')
for recipe in all_recipes:
    for svg in svg_dict:
        if recipe['glass'] == svg['name']:
            recipe['Mask'] = svg['mask']
            recipe['Path'] = svg['path']
            recipe['Mask_Height'] = svg['maskHeight']
            recipe['Mask_Top_Margin'] = svg['maskTopMargin']

# %%
svg_masks = list(svg_data['mask'])

# %%
all_recipes_copy = all_recipes

# %%
for recipe in all_recipes_copy:
    recipe['Ingredients'] = []
    
    #find total glass volume
    total_glass_volume = recipe["glass_size"]
    #set total liquid measure to 0
    total_liquid_measure = 0
    for measure, ingredient in recipe['recipe']:
        measure = measure.strip()
        if measure == "add":
            recipe['Garnish_Instructions'] = measure
            recipe['Garnish'] = ingredient
#         elif ingredient == "pimm's cup":#pimm's cup did not make it onto out liquids list
#             pass

        else:
            this_ing = {}
            #add to lists
            this_ing['Liquid'] = ingredient
            this_ing['Measure'] = measure
        ### CONVERTING MEASURES TO FLOAT ###
            #split measure on spaces
            split_measure = measure.split(" ")

            #if measure is compound fraction,
            if len(split_measure) > 2:
                #recombine compound fraction
                measure = split_measure[0]+" "+split_measure[1]
                #convert to float
                measure_float = float(sum(Fraction(s) for s in measure.split()))
                #add to dict
                this_ing['Measure_Float'] = measure_float
                #add measure to drink's total measure
                total_liquid_measure += measure_float
            #if measure is an integer,
            elif len(split_measure) > 1:
                #convert to float
                measure_float = float(sum(Fraction(s) for s in split_measure[0].split()))
                #if unit is smaller than oz, convert measure to oz
                if split_measure[1][:3] == "tsp":
                    measure_float = measure_float / 6
                elif split_measure[1][:4] == "dash":
                    measure_float = measure_float / 32
                elif split_measure[1][:6] == "splash":
                    measure_float = measure_float / 5
                #add to float list
                this_ing['Measure_Float'] = measure_float
                #add measure to drink's total measure
                total_liquid_measure += measure_float
            #if measure if fill,
            elif split_measure[0] == "fill":
                #calculate remaining volume
                remaining_volume = float(total_glass_volume) - float(total_liquid_measure)
                #set fill measure to half remaining volume
                measure_float = float(remaining_volume / 2)
                #add to float list
                this_ing['Measure_Float'] = measure_float
            else:
                measure_float = float(0)
                this_ing['Measure_Float'] = measure_float
        recipe['Ingredients'].append(this_ing)

# %%
for recipe in all_recipes_copy:
#     print(recipe['name'])
    vols = []
    for ingredient in recipe['Ingredients']:
#         print(ingredient)
        vols.append(ingredient['Measure_Float'])
        if ingredient['Liquid'][:6] == "rose's":
            ingredient['Liquid'] = ingredient['Liquid'][7:]
        elif ingredient['Liquid'][:8] =="peychaud": 
            ingredient['Liquid'] = "peychauds bitters"
    recipe['Total_Volume'] = sum(vols)

# %%
for recipe in all_recipes_copy:
    recipe['Cocktail_Name'] = recipe.pop('name')
    recipe['Category'] = recipe.pop('category')
    recipe['Instructions'] = recipe.pop('instructions')
    recipe['Glass_Size'] = recipe.pop('glass_size')
    recipe['Glass'] = recipe.pop('glass')
    recipe.pop('recipe')

# %%
all_recipes_copy[2]
# Out:
# {'Mask': 'm 4.5662649,9.3496885 c 0,0 0.1148621,2.8743365 0.227216,4.9927245 0.047721,0.899758 0.04285,2.164336 0.065399,3.065077 0.03123,1.247489 -0.00404,2.495605 0.017914,3.743292 0.028802,1.636893 -0.049916,10.053147 0.1059161,11.68286 0.4942612,5.169061 0.3676916,7.592307 1.6624482,9.336233 0.9872106,1.329688 2.2579847,2.033887 3.7907238,2.47637 2.410543,0.695894 11.034041,0.946 12.396225,0.946 1.362184,0 9.985682,-0.250106 12.396225,-0.946 1.532739,-0.442483 2.803513,-1.146682 3.790724,-2.47637 1.294756,-1.743926 1.168187,-4.167172 1.662448,-9.336233 0.155832,-1.629713 0.07711,-10.045967 0.105916,-11.68286 0.02195,-1.247687 -0.01332,-2.495803 0.01791,-3.743292 0.02255,-0.900741 0.01768,-2.165319 0.0654,-3.065077 0.112354,-2.118388 0.210679,-4.9927245 0.210679,-4.9927245 z',
#  'Path': 'M 10.435878,44.646245 C 8.9031392,44.203762 7.6323652,43.499563 6.6451542,42.169875 5.3503982,40.425949 5.4769672,38.096247 4.9827062,32.927186 4.8268742,31.297473 4.9055962,22.787675 4.8767902,21.150782 c -0.02195,-1.247687 0.01332,-2.495803 -0.01791,-3.743292 -0.02255,-0.900741 -0.01768,-2.165319 -0.0654,-3.065077 -0.112354,-2.118388 -0.213078,-6.1542813 -0.309898,-6.3156412 -0.136137,-0.2269 -0.703363,-0.26995 -0.793523,-0.0212 -0.140372,0.38731 -0.03464,4.1874652 0.01411,6.2803702 0.01949,0.836692 -0.01345,1.671657 0,2.508468 0.02034,1.265897 -0.01669,2.532018 0,3.797968 0.0217,1.646251 -0.01706,3.289509 0,4.935814 0.01825,1.761903 0.04677,3.850936 0.04677,5.612702 0,2.367665 0.128162,5.671506 0.187089,8.038438 l 0.140316,5.636126 c 0.02419,0.971664 0.02004,2.318474 0.04677,3.290071 0.04206,1.528566 0.128176,3.066915 0.29905,4.393401 0.108798,0.844596 0.08364,1.723209 0.630718,2.300004 0.655629,0.691249 2.712594,0.900506 2.712594,0.900506 -0.5809,0.29045 7.0093908,0.746829 7.0093908,0.746829 h 16.110474 c 0,0 7.590292,-0.456379 7.009392,-0.746829 0,0 2.056964,-0.209257 2.712594,-0.900506 0.547073,-0.576795 0.52192,-1.455408 0.630718,-2.300004 0.170873,-1.326486 0.256987,-2.864835 0.299049,-4.393401 0.02674,-0.971597 0.02258,-2.318407 0.04677,-3.290071 l 0.140317,-5.636126 c 0.05893,-2.366932 0.187089,-5.670773 0.187089,-8.038438 0,-1.761766 0.02852,-3.850799 0.04677,-5.612702 0.01706,-1.646305 -0.0217,-3.289563 0,-4.935814 0.01668,-1.26595 -0.02034,-2.532071 0,-3.797968 0.01345,-0.836811 -0.01949,-1.671776 0,-2.508468 0.04875,-2.092905 0.154479,-5.8930602 0.01411,-6.2803702 -0.09016,-0.24875 -0.657386,-0.2057 -0.793523,0.0212 -0.09682,0.1613599 -0.197545,4.1972532 -0.309899,6.3156412 -0.04772,0.899758 -0.04285,2.164336 -0.0654,3.065077 -0.03123,1.247489 0.004,2.495605 -0.01791,3.743292 -0.0288,1.636893 0.04992,10.146691 -0.105916,11.776404 -0.494261,5.169061 -0.367691,7.498763 -1.662448,9.242689 -0.987211,1.329688 -2.257985,2.033887 -3.790724,2.47637 -2.410543,0.695894 -11.034041,0.946 -12.396225,0.946 -1.362184,0 -9.985682,-0.250106 -12.396225,-0.946 z',
#  'Mask_Height': 36.5,
#  'Mask_Top_Margin': 9.3,
#  'Ingredients': [{'Liquid': 'apple schnapps',
#    'Measure': '3 oz',
#    'Measure_Float': 3.0},
#   {'Liquid': 'cinnamon schnapps', 'Measure': '1 oz', 'Measure_Float': 1.0},
#   {'Liquid': 'cinnamon schnapps', 'Measure': '1 oz', 'Measure_Float': 1.0}],
#  'Garnish_Instructions': 'add',
#  'Garnish': 'green apple slice',
#  'Total_Volume': 5.0,
#  'Cocktail_Name': 'Apple Pie',
#  'Category': 'Cordials and Liqueurs',
#  'Instructions': 'Pour into ice-filled old-fashioned glass. Garnish with apple and top with cinnamon.',
#  'Glass_Size': 6,
#  'Glass': 'old_fashioned'}

# %%
#AI Recipes load

#create glass list
glasses = []
for i in range(len(all_recipes)):
    glasses.append(all_recipes[i]["Glass"])
glasses = list(set(glasses))

df = pd.DataFrame(all_recipes)

#create glass sizes list
glass_sizes = []
for glass in glasses:
    sizes = df.loc[df["Glass"] == glass, "Glass_Size"]
    glass_sizes.append(list(sizes)[0])
    
#create glass size dictionary
glass_size_dict = {}
for i in range(len(glasses)):
    glass_size_dict[glasses[i]] = glass_sizes[i]
glass_size_dict

text_files = ["MACKs_AI_Classics_2.txt", "MACKs_AI_Classics_5.txt", "MACKs_AI_Classics_10.txt"]

def parse_ai_text(text_file):
    #to track how many records are dropped due to what criteria
    all_lines = 0
    good_cocktails = 0
    too_many_ingredients = 0
    wrong_glass = 0
    bad_instructions = 0
    bad_volume = 0
    
    #open text file to read
    with open(text_file, "r") as file:
        for line in file:
    #         print(line)
            #split line
            split_line = line.split(" - ")
            all_lines += 1

            #get name
            name = split_line[0]
            print(f"COCKTAIL NAME: {name}")

            #get glass
            glass = split_line[1]
            print(f"GLASS NAME: {glass}")

            #get instructions
            instructions = split_line[-1:][0][:-1]
            instructions = re.sub(r'["]', '\'', instructions)
            print(f"INSTRUCTIONS: {instructions}")


            garnish_list = []
            measure_list = []
            measure_float_list = []
            liquid_list = []
            total_volume = 0
            try:
                glass_volume = glass_size_dict[glass]
            except KeyError:
                glass_volume = 0
            
            recipe = {}

            #get number of ingredients (split length minus name, glass, instructions)
            ingredients_length = len(split_line) - 3
            #loop over ingredients
            for i in range(3, ingredients_length + 2):
                this_ing = {}
                ingredient = split_line[i]

                #if ingredient begins with 'add', its a garnish
                if ingredient[:3] == "add":
                    recipe['Garnish'] = ingredient.split("add ")[1]
                    recipe['Garnish_Instructions'] = ingredient.split("add ")[0]
                    
                    

                #if ingredient starts with 'fill',
                elif split_line[i][:4] == "fill":
                    measure_list.append("fill")
                    print("MEASURE: fill")

                    #get liquid ingredient
                    liquid = split_line[i].split("fill ")[1]
                    liquid_list.append(liquid.strip())
                    print(f"LIQUID NAME: {liquid}")

                    #calculate measure_float
                    remaining_volume = float(glass_volume) - float(total_volume)
                    measure_float = float(remaining_volume / 2)
                    measure_float_list.append(measure_float)
                    print(f"MEASURE FLOAT: {measure_float}")

                   


                else:
                    try:
                        #if ingredient begins with number, its a meausure and a liquid
                        int(ingredient[:1])
                    except ValueError:
                        pass
                    #split ingredient on spaces
                    split_ingredient = ingredient.split(" ")                

                    #loop over splits
                    for j in range(len(split_ingredient)):
                        #if split is unit of measure, check for compound fraction
                        if split_ingredient[j] in ["oz", "dash", "splash", "tsp"]:
                            units = split_ingredient[j].strip()                        

                            #if j-2 > -1, there is a compound fraction
                            if j-2 > -1:
                                #get 2 parts of compound fraction
                                fraction = split_ingredient[j-1].strip()
                                whole_number = split_ingredient[j-2].strip()                           

                                #recombine compound fraction
                                measure = whole_number+ " " +fraction
                                measure_list.append(measure + " " + units)
                                print(f"MEASURE: {measure + ' ' + units}")

                                #get liquid ingredient
                                liquid = ingredient.split(measure + " " + units)[1]
                                liquid_list.append(liquid.strip())                            
                                print(f"LIQUID: {liquid}")

                                #convert measure to float
                                try:
                                    measure_float = float(sum(Fraction(s) for s in measure.split()))
                                except ValueError:
                                    pass

                                #if unit is smaller than oz, convert measure to oz
                                if ingredient[:3] == "tsp":
                                    measure_float = measure_float / 6
                                elif ingredient[:4] == "dash":
                                    measure_float = measure_float / 32
                                elif ingredient[:6] == "splash":
                                    measure_float = measure_float / 5
                                measure_float_list.append(measure_float)
                                print(f"MEASURE FLOAT: {measure_float}")

                                #add measure to total volume
                                total_volume += measure_float

                            else: #just a single number or fraction
                                #get measure
                                measure = split_ingredient[j-1].strip()
                                measure_list.append(measure + " " + units)
                                print(f"MEASURE: {measure + ' ' + units}")


                                #get liquid ingredient
                                liquid = ingredient.split(measure + " " + units)[1]
                                liquid_list.append(liquid.strip())
                                print(f"LIQUID: {liquid}")

                                #convert to float
                                measure_float = float(sum(Fraction(s) for s in measure.split()))
                                #if unit is smaller than oz, convert measure to oz
                                if ingredient[:3] == "tsp":
                                    measure_float = measure_float / 6
                                elif ingredient[:4] == "dash":
                                    measure_float = measure_float / 32
                                elif ingredient[:6] == "splash":
                                    measure_float = measure_float / 5
                                measure_float_list.append(measure_float)
                                print(f"MEASURE FLOAT: {measure_float}")

                                #add measure to total volume    
                                total_volume += measure_float

            #if more than 6 ingredients, skip
            if len(split_line) > 10:
#                 print("INGREDIENTS ERRORRRRRRRRRRR")
                too_many_ingredients += 1
                pass

            elif glass not in glasses:
#                 print("GLASS ERRORRRRRRRRRR")
                wrong_glass += 1
                pass

            elif instructions[:3] == "add":
#                 print("INSTRUCTIONS ERRORRRRRRRRR")
                bad_instructions += 1
                pass 

            elif total_volume > glass_volume:
#                 print("VOLUME ERRORRRRRRRRRRRR")
                bad_volume += 1

            else:
                good_cocktails += 1
                
                #insert cocktail name and instructions into cocktail table
                recipe['Cocktail_Name'] = name
                print(name)
                recipe['Instructions'] = instructions
                recipe['Glass'] = glass
                recipe['Category'] = 'AI Instant Classic'
                
                
                
                for i in range(len(liquid_list)):
                    this_ing = {}
                    this_ing['Liquid'] = liquid_list[i]
                    this_ing['Measure'] = measure_list[i]
                    this_ing['Measure_Float'] = measure_float_list[i]
                    recipe['Ingredients'].append(this_ing)
                print(recipe)
                all_recipes.append(recipe)
    
            print("----------------------")
    

    # print(all_lines, too_many_ingredients, wrong_glass, bad_instructions, bad_volume, good_cocktails)
    print("####################################")


for file in text_files:
    parse_ai_text(file)
# Out:
# COCKTAIL NAME: Black Hawk
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  ginger ale or soda water
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Biffy Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake first four ingredients with ice and strain into ice-filled Collins glass. Garnis
# MEASURE: 1 1/2 oz
# LIQUID:  apricot flavored brandy
# MEASURE FLOAT: 1.5
# MEASURE: 1 oz
# LIQUID:  batavia arrack or light rum
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  creme de banana
# MEASURE FLOAT: 0.5
# MEASURE: fill
# LIQUID NAME: allspice liqueur (pimento dram)
# MEASURE FLOAT: -1.5
# MEASURE: fill
# LIQUID NAME: chilled champagne
# MEASURE FLOAT: -1.5
# ----------------------
# COCKTAIL NAME: Bull Shot
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Muddle 4 basil leaves in mixing glass. Add remaining ingredients. Shake with ice and double-strain into chilled cocktail glass. Add orange twist
# MEASURE: 3/4 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.75
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  passion fruit juice
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Saronno Colada (Nutty Colada)
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 3 oz
# LIQUID:  coconut milk
# MEASURE FLOAT: 3.0
# ----------------------
# COCKTAIL NAME: Bourbon Cobbler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bourbon Cooler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Apple Pie Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 3/4 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 0.75
# MEASURE: 1 oz
# LIQUID:  apple brandy or applejack
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  pineapple juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Saronno
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Brandy Crusta Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  sugar syrup
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Brandy Crusta Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  rose's lime juice
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Canadian Cherry
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Stir with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 oz
# LIQUID:  pineapple juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Brandy Crusta Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  rose's lime juice
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Bermuda Rose
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Pour rum into highball glass over ice cubes. Fill with carbonated water and stir.
# MEASURE: 1 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 1.0
# MEASURE: fill
# LIQUID NAME: ginger ale or soda water
# MEASURE FLOAT: -0.5
# ----------------------
# COCKTAIL NAME: Brandy Squirt
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.5
# MEASURE: 1/4 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 0.25
# ----------------------
# COCKTAIL NAME: The Blinker
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 1/2 oz
# LIQUID:  citrus flavored vodka
# MEASURE FLOAT: 1.5
# MEASURE: 1/4 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 0.25
# MEASURE: 1/4 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.25
# MEASURE: 1/4 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.25
# MEASURE: 1/4 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.25
# MEASURE: 1 oz
# LIQUID:  orange bitters (if desired)
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Canadian Cherry
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 oz
# LIQUID:  pineapple juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Brandy Crusta Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 2 oz
# LIQUID:  carbonated water
# MEASURE FLOAT: 2.0
# MEASURE: 2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 2.0
# MEASURE: 1 oz
# LIQUID:  light cream (if desired)
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Pink Paradise
# GLASS NAME: Hurricane Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: The Blinker
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Muddle 4 basil leaves in mixing glass. Add remaining ingredients. Shake with ice and double-strain into chilled cocktai
# MEASURE: 1 1/2 oz
# LIQUID:  blanco tequila
# MEASURE FLOAT: 1.5
# MEASURE: 1 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  passion fruit juice
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bourbon Cooler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  anisette
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Chaplin
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Brandy Crusta Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 2 oz
# LIQUID:  carbonated water
# MEASURE FLOAT: 2.0
# MEASURE: 2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 2.0
# MEASURE: 1 oz
# LIQUID:  light cream (if desired)
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Palmetto Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir first three ingredients in ice-filled Collins glass. Fill with soda water and stir briefly. Garnish with lime wedge.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  ginger ale or soda water
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bourbon Cooler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  white creme de cacao
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Black Hawk Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass.
# MEASURE: 1 1/2 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 1.5
# MEASURE: 1 1/2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.5
# ----------------------
# COCKTAIL NAME: The Blinker
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 1/2 oz
# LIQUID:  blanco tequila
# MEASURE FLOAT: 1.5
# MEASURE: 3/4 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.75
# MEASURE: 3/4 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.75
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Brandy Alexander
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir first three ingredients in ice-filled Collins glass. Fill with soda water and stir gently. Garnish with ora
# MEASURE: 1/2 oz
# LIQUID:  campari
# MEASURE FLOAT: 0.5
# MEASURE: 3/4 oz
# LIQUID:  fresh grapefruit juice
# MEASURE FLOAT: 0.75
# MEASURE: 1/2 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 2 oz
# LIQUID:  ginger ale or soda water
# MEASURE FLOAT: 2.0
# ----------------------
# COCKTAIL NAME: Black Hawk
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  ginger ale or soda water
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Pink Lady Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass.
# MEASURE: 3/4 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.75
# MEASURE: 3/4 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 0.75
# ----------------------
# COCKTAIL NAME: Brandy Crusta Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass.
# MEASURE: 3/4 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.75
# MEASURE: 1/2 oz
# LIQUID:  anisette
# MEASURE FLOAT: 0.5
# MEASURE: 1 1/2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.5
# ----------------------
# COCKTAIL NAME: The Blood Orange
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice, strain i
# MEASURE: 1 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  each orange juice and sweet sherry
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# MEASURE: 2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 2.0
# MEASURE: 1 oz
# LIQUID:  coconut milk
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bronx SIlver Cocktail
# GLASS NAME: Sour Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 1/2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.5
# MEASURE: 1/2 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bloody Maria
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice, strain into collins glass, and sprin
# MEASURE: 1 oz
# LIQUID:  creme de banana
# MEASURE FLOAT: 1.0
# MEASURE: 2 oz
# LIQUID:  each orange juice and sweet sherry
# MEASURE FLOAT: 2.0
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# MEASURE: 2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 2.0
# MEASURE: 1 oz
# LIQUID:  coconut milk
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bourbon Cooler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Muddle cucumber, sage, and lime juice in mixing glass. Add tequila and syrup with ice and shake. Double-strain
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  ginger ale or soda water
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Brandy Crusta Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  absinthe substitute
# MEASURE FLOAT: 0.5
# MEASURE: 1/4 oz
# LIQUID:  maraschino liqueur
# MEASURE FLOAT: 0.25
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bronx Golden Cocktail
# GLASS NAME: Sour Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Black Hawk
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  whiskey barrel bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Santiago Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: 1 oz c
# MEASURE: 1 oz
# LIQUID:  pineapple juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  each cranberry juice and orange juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  each orange juice and sweet sherry
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# MEASURE: 2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 2.0
# ----------------------
# COCKTAIL NAME: Bourbon Cobbler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Brandy Flip
# GLASS NAME: Sour Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 1/2 oz
# LIQUID:  cherry  flavored brandy
# MEASURE FLOAT: 1.5
# MEASURE: 1/2 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.5
# MEASURE: 1/4 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 0.25
# MEASURE: 1/4 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.25
# ----------------------
# COCKTAIL NAME: Bull's Milk
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 3 oz
# LIQUID:  unsweetened grape juice
# MEASURE FLOAT: 3.0
# MEASURE: 3 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 3.0
# MEASURE: 1 1/2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.5
# MEASURE: 1/2 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Long Island Iced Tea
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 3/4 oz
# LIQUID:  blanco tequila
# MEASURE FLOAT: 0.75
# MEASURE: 3/4 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.75
# MEASURE: 3/4 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.75
# ----------------------
# COCKTAIL NAME: Saronno
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add orange twist.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bourbon Cooler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Lemonade (Egg)
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Muddle the cucumber, mint leaves, and syrup. Add vodka and lime juice. Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Canadian Cherry
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Stir with ice and strain into chilled cocktail glass.
# MEASURE: 1 oz
# LIQUID:  pineapple juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Brandy Alexander
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  cherry  flavored brandy
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Cherry Fizz
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Shake with ice, strain into collins glass, and sprinkle nutmeg on top.
# MEASURE: 2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 2.0
# MEASURE: 1 oz
# LIQUID:  coconut milk
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Saronno
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bourbon Cooler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Palmetto Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Muddle cucumber, sage, and lime juice in mixing glass. Add tequila and syrup with ice and shake. Double-strain into ice-filled old-fashioned glass. Add lemon
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  ginger ale or soda water
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bourbon Cooler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Brandy and Soda
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 1.0
# MEASURE: fill
# LIQUID NAME: ginger ale or soda water
# MEASURE FLOAT: -0.5
# ----------------------
# COCKTAIL NAME: Bourbon Cooler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  white creme de cacao
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bourbon Cobbler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Pink Lady Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass.
# MEASURE: 1 1/2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.5
# ----------------------
# COCKTAIL NAME: Saronno Rose
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Muddle whole strawberry in mixing glass. Add remaining ingredients. Shake with ice and double-strain into chilled cocktail glass. Garnish with lime.
# MEASURE: 1/2 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.5
# MEASURE: 1/4 oz
# LIQUID:  agave nectar
# MEASURE FLOAT: 0.25
# ----------------------
# COCKTAIL NAME: The Blood Orange
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into chilled cocktail glass. Garnish with lime.
# MEASURE: 1 oz
# LIQUID:  whiskey barrel bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bourbon Cobbler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: The Blinker
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 1/2 oz
# LIQUID:  citrus flavored vodka
# MEASURE FLOAT: 1.5
# MEASURE: 1/4 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 0.25
# MEASURE: 1/4 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.25
# MEASURE: 1/4 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.25
# MEASURE: 1/4 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.25
# ----------------------
# COCKTAIL NAME: Chaplin
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemo
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  ginger ale or soda water
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Black Hawk Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass.
# MEASURE: 1 1/2 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 1.5
# MEASURE: 1 1/2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.5
# ----------------------
# COCKTAIL NAME: Brandy Alexander
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into chilled cocktail glass. Garnish with lime.
# MEASURE: 1/2 oz
# LIQUID:  campari
# MEASURE FLOAT: 0.5
# MEASURE: 3/4 oz
# LIQUID:  fresh grapefruit juice
# MEASURE FLOAT: 0.75
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bourbon Cooler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Muddle cucumber, sage, and lime juice in mixing glass. Add tequila and syrup with ice an
# MEASURE: 1/2 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  ginger ale or soda water
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Purple Passion Iced Tea
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Prairie Chicken
# GLASS NAME: Red-Wine Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  orange bitters (if desired)
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bourbon Cobbler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Carrol Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Muddle 4 basil leaves in mixing glass. Add remaining ingredients. Shake with ice and double-str
# MEASURE: 1 oz
# LIQUID:  batavia arrack or light rum
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  passion fruit juice
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Black Hawk
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: The Blinker
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into ice-filled old-fashioned glass. Garnish wi
# MEASURE: 1 1/2 oz
# LIQUID:  blanco tequila
# MEASURE FLOAT: 1.5
# MEASURE: 1/2 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.5
# MEASURE: fill
# LIQUID NAME: ginger ale or soda water
# MEASURE FLOAT: -1.0
# ----------------------
# COCKTAIL NAME: Cherry Blossom Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# MEASURE: 2 oz
# LIQUID:  light cream (if desired)
# MEASURE FLOAT: 2.0
# ----------------------
# COCKTAIL NAME: Brandy Crusta Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 3/4 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.75
# MEASURE: 1/4 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.25
# MEASURE: 1 oz
# LIQUID:  orange bitters (if desired)
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Brandy Crusta Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 3/4 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.75
# MEASURE: 1/4 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.25
# MEASURE: 1 oz
# LIQUID:  orange bitters (if desired)
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Black Hawk
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into chilled cocktail glass.
# MEASURE: 1 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  whiskey barrel bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: The Blood Orange
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Cherry Fizz
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Shake with ice, strain into collins glass, and sprinkle nutmeg on top.
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# MEASURE: 2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 2.0
# MEASURE: 1 oz
# LIQUID:  coconut milk
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Cherry Blossom Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# ----------------------
# COCKTAIL NAME: Rum Screwdriver
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Stir first three ingredients in ice-filled Collins glass. Fill with soda water and stir gently. Garnish with orange and lemon and serve with a str
# MEASURE: 1 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 2 oz
# LIQUID:  ginger ale or soda water
# MEASURE FLOAT: 2.0
# ----------------------
# COCKTAIL NAME: Brandy Flip
# GLASS NAME: Sour Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 1/2 oz
# LIQUID:  cherry  flavored brandy
# MEASURE FLOAT: 1.5
# MEASURE: 1/2 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Champagne Flamingo
# GLASS NAME: Champagne Flute
# INSTRUCTIONS: Shake vodka and Campari with ice. Strain into chilled champagne flute and top with Champagne.
# MEASURE: 3/4 oz
# LIQUID:  campari
# MEASURE FLOAT: 0.75
# MEASURE: 5 oz
# LIQUID:  chilled champagne
# MEASURE FLOAT: 5.0
# ----------------------
# COCKTAIL NAME: Brandy Squirt
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.5
# MEASURE: fill
# LIQUID NAME: ginger ale or soda water
# MEASURE FLOAT: -0.25
# ----------------------
# COCKTAIL NAME: Brandy Crusta Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  rose's lime juice
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Black Hawk
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  apricot flavored brandy
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Carrol Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake first three ingredients with ice and strain into ice-filled Collins glass. Garnish with orange and lime.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Caribbean Cruise
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Saronno
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bourbon Cobbler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Black Hawk Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass.
# MEASURE: 1 1/2 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 1.5
# MEASURE: 1 1/2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.5
# ----------------------
# COCKTAIL NAME: Bourbon Cobbler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: The Blinker
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1 1/2 oz
# LIQUID:  citrus flavored vodka
# MEASURE FLOAT: 1.5
# MEASURE: 1/4 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 0.25
# MEASURE: 1/4 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.25
# MEASURE: 1/4 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.25
# MEASURE: 1/4 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.25
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bulldog Highball
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: fill
# LIQUID NAME: ginger ale or soda water
# MEASURE FLOAT: -0.5
# ----------------------
# COCKTAIL NAME: Canadian Cherry
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  apricot flavored brandy
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Blue Margarita
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir first three ingredients in ice-filled Collins glass. Fill with sparkling wine. Garnish with peach.
# MEASURE: 1 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 2 oz
# LIQUID:  ginger ale or soda water
# MEASURE FLOAT: 2.0
# ----------------------
# COCKTAIL NAME: Saronno
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Brandy Alexander
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1/2 oz
# LIQUID:  campari
# MEASURE FLOAT: 0.5
# MEASURE: 3/4 oz
# LIQUID:  fresh grapefruit juice
# MEASURE FLOAT: 0.75
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Margarita Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Muddle 4 basil leaves in mixing glass. Add remaining ingredients. Shake with ice and double-strain into chilled cocktail gl
# MEASURE: 1/2 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  passion fruit juice
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bourbon Cooler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1/2 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Brandy Alexander
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1/2 oz
# LIQUID:  campari
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bourbon Cobbler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Saronno
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass.
# MEASURE: 3/4 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.75
# MEASURE: 1/4 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 0.25
# ----------------------
# COCKTAIL NAME: Brandy Crusta Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 3/4 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.75
# MEASURE: 1/2 oz
# LIQUID:  apricot flavored brandy
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  sugar syrup
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bourbon Cobbler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Cherry Blossom Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# ----------------------
# COCKTAIL NAME: Santana Sling
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1 1/2 oz
# LIQUID:  citrus flavored vodka
# MEASURE FLOAT: 1.5
# MEASURE: 1/4 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 0.25
# MEASURE: 1/4 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.25
# MEASURE: 1/4 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.25
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Water Lily
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 3/4 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.75
# MEASURE: 3/4 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.75
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Black Hawk
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Canadian Cherry
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Stir with ice and strain into chilled cocktail glass.
# MEASURE: 1 oz
# LIQUID:  pineapple juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Brandy Flip
# GLASS NAME: Sour Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  tawny port
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  cherry  flavored brandy
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Prairie Oyster Cocktail
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into collins glass. Add several ice cubes, fill with soda water, and stir. Garnish with orange, lem
# MEASURE: 1 oz
# LIQUID:  creme de banana
# MEASURE FLOAT: 1.0
# MEASURE: 2 oz
# LIQUID:  each orange juice and sweet sherry
# MEASURE FLOAT: 2.0
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: fill
# LIQUID NAME: club soda
# MEASURE FLOAT: -2.0
# ----------------------
# COCKTAIL NAME: Champagne Velvet
# GLASS NAME: Champagne Flute
# INSTRUCTIONS: Pour very carefully, in order given, into champagne flute so that the stout and champagne don't mix.
# MEASURE: 5 oz
# LIQUID:  chilled champagne
# MEASURE FLOAT: 5.0
# ----------------------
# COCKTAIL NAME: The Blood Orange
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  creme de cacao (white)
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  light cream (if desired)
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Carrol Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 1/2 oz
# LIQUID:  absinthe substitute
# MEASURE FLOAT: 1.5
# ----------------------
# COCKTAIL NAME: Bulldog Highball
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: fill
# LIQUID NAME: ginger ale or soda water
# MEASURE FLOAT: -0.5
# ----------------------
# COCKTAIL NAME: Champagne Flamingo
# GLASS NAME: Champagne Flute
# INSTRUCTIONS: Shake vodka and Campari with ice. Strain into chilled champagne flute and top with Champagne. Add orange twist.
# MEASURE: 3/4 oz
# LIQUID:  campari
# MEASURE FLOAT: 0.75
# MEASURE: 5 oz
# LIQUID:  chilled champagne
# MEASURE FLOAT: 5.0
# ----------------------
# COCKTAIL NAME: Bourbon Highball
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  maraschino liqueur
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Carroll Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Champagne Flamingo
# GLASS NAME: Champagne Flute
# INSTRUCTIONS: Shake vodka and Campari with ice. Strain into chilled champagne flute and top with Champagne. Add orange twist.
# MEASURE: 3/4 oz
# LIQUID:  campari
# MEASURE FLOAT: 0.75
# MEASURE: 5 oz
# LIQUID:  chilled champagne
# MEASURE FLOAT: 5.0
# ----------------------
# COCKTAIL NAME: Brandy Crusta Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 3/4 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.75
# MEASURE: 1/4 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.25
# MEASURE: 1 oz
# LIQUID:  orange bitters (if desired)
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: The Blood Orange
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Canadian Cherry
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Stir with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 oz
# LIQUID:  pineapple juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Black Hawk Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass.
# MEASURE: 1 1/2 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 1.5
# MEASURE: 1 oz
# LIQUID:  orange bitters (if desired)
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Sand-Martini Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass.
# MEASURE: 1 1/2 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 1.5
# MEASURE: 1 1/2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.5
# ----------------------
# COCKTAIL NAME: Chapel Hill
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir first three ingredients in ice-filled Collins glass. Fill with soda water and stir briefly. Garnish with lime wedge.
# MEASURE: 1/2 oz
# LIQUID:  batavia arrack or light rum
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 2 oz
# LIQUID:  ginger ale or soda water
# MEASURE FLOAT: 2.0
# ----------------------
# COCKTAIL NAME: Brandy Flip
# GLASS NAME: Sour Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  tawny port
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  cherry  flavored brandy
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Saronno Colada (Nutty Colada)
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Put in an electric blender with 2 cups of crushed ice and blend at high speed for a short time. Pour into a collins glass and serve with a straw.
# MEASURE: 3 oz
# LIQUID:  coconut milk
# MEASURE FLOAT: 3.0
# MEASURE: 3 oz
# LIQUID:  crushed pineapple
# MEASURE FLOAT: 3.0
# ----------------------
# COCKTAIL NAME: The Blood Orange
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  whiskey barrel bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Santana Sling
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twi
# MEASURE: 1 oz
# LIQUID:  cherry  flavored brandy
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 1.0
# MEASURE: fill
# LIQUID NAME: ginger ale or soda water
# MEASURE FLOAT: -1.0
# ----------------------
# COCKTAIL NAME: Bourbon Cooler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  white creme de cacao
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  light cream (if desired)
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bourbon Cooler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  anisette
# MEASURE FLOAT: 0.5
# MEASURE: 1 1/2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.5
# ----------------------
# COCKTAIL NAME: Brandy Alexander
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1/2 oz
# LIQUID:  campari
# MEASURE FLOAT: 0.5
# MEASURE: 3/4 oz
# LIQUID:  fresh grapefruit juice
# MEASURE FLOAT: 0.75
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Hair Raiser
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: The Beautiful Day
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 3/4 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 0.75
# MEASURE: 3/4 oz
# LIQUID:  benedictine
# MEASURE FLOAT: 0.75
# MEASURE: 3 oz
# LIQUID:  absinthe or pastis
# MEASURE FLOAT: 3.0
# MEASURE: 3 oz
# LIQUID:  peychaud's bitters
# MEASURE FLOAT: 3.0
# ----------------------
# COCKTAIL NAME: Brandy Squirt
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1/2 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.5
# MEASURE: 1/4 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 0.25
# ----------------------
# COCKTAIL NAME: Brandy Crusta Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  rose's lime juice
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Bourbon Cobbler
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Black Hawk
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1/2 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Betsy Ross Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Champagne Flamingo
# GLASS NAME: Champagne Flute
# INSTRUCTIONS: Shake vodka and Campari with ice. Strain into chilled champagne flute and top with Champagne. Add orange twist.
# MEASURE: 3/4 oz
# LIQUID:  campari
# MEASURE FLOAT: 0.75
# MEASURE: 5 oz
# LIQUID:  chilled champagne
# MEASURE FLOAT: 5.0
# ----------------------
# COCKTAIL NAME: Pink Pussycat
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  cold brewed chai tea
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.5
# MEASURE: 1/4 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 0.25
# ----------------------
# COCKTAIL NAME: Bulldog Highball
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# MEASURE: 2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 2.0
# ----------------------
# COCKTAIL NAME: Saronno
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass.
# MEASURE: 3/4 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.75
# MEASURE: 1/4 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 0.25
# ----------------------
# COCKTAIL NAME: Santana Sling
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Shake first three ingredients with ice
# MEASURE: 1 1/2 oz
# LIQUID:  batavia arrack or light rum
# MEASURE FLOAT: 1.5
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  ginger ale or soda water
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Brandy Squirt
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.5
# MEASURE: 1/4 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 0.25
# ----------------------
# COCKTAIL NAME: Cherry Fizz
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Shake with ice, strain into collins glass, and sprinkle nutmeg on top.
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# MEASURE: 2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 2.0
# MEASURE: 1 oz
# LIQUID:  coconut milk
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Saronno Colada (Nutty Colada)
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 3 oz
# LIQUID:  coconut milk
# MEASURE FLOAT: 3.0
# ----------------------
# COCKTAIL NAME: Brandy Crusta Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 1/2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.5
# MEASURE: 1/2 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Brandy Flip
# GLASS NAME: Sour Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 1/2 oz
# LIQUID:  cherry  flavored brandy
# MEASURE FLOAT: 1.5
# MEASURE: 2 oz
# LIQUID:  light cream (if desired)
# MEASURE FLOAT: 2.0
# ----------------------
# COCKTAIL NAME: Bloody Maria
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Bull Shot
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Muddle 4 basil leaves in mixing glass. Add remaining ingredients. Shake with ice and double-strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 3/4 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.75
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  passion fruit juice
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Bourbon Crusta
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  white creme de cacao
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Saronno Colada (Nutty Colada)
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 3 oz
# LIQUID:  coconut milk
# MEASURE FLOAT: 3.0
# ----------------------
# COCKTAIL NAME: Saronno Colada (Nutty Colada)
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# ...
# MEASURE FLOAT: 0.0
# ----------------------
# COCKTAIL NAME: Sherry Sangaree
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake first four ingredients with ice. Strain into chilled highball glass over
# MEASURE: 1 1/2 oz
# LIQUID:  blanco tequila
# MEASURE FLOAT: 1.5
# MEASURE: 1 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 1.0
# MEASURE: 3/4 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.75
# ----------------------
# COCKTAIL NAME: Back Porch Swizzle
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Pour ingredients into highball glass over ice cubes and fill with ginger ale. Stir.
# MEASURE: 6 oz
# LIQUID:  cold water
# MEASURE FLOAT: 6.0
# ----------------------
# COCKTAIL NAME: Wallick Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir well with cracked ice and strain into cocktail glass. Garnish with cherry.
# MEASURE: 3/4 oz
# LIQUID:  dry gin
# MEASURE FLOAT: 0.75
# MEASURE: 3/4 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.75
# MEASURE: 1/2 oz
# LIQUID:  dubonnet
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Heather Blush
# GLASS NAME: Champagne Flute
# INSTRUCTIONS: Stir with ice and strain into chilled cocktail glass. Garnish with pickle.
# MEASURE: 3/4 oz
# LIQUID:  benedictine
# MEASURE FLOAT: 0.75
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Weep-No-More Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1 1/2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.5
# MEASURE: 1/4 oz
# LIQUID:  apricot flavored brandy
# MEASURE FLOAT: 0.25
# MEASURE: 1/4 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.25
# ----------------------
# COCKTAIL NAME: Grasshopper Cocktail
# GLASS NAME: Sour Glass
# INSTRUCTIONS: Stir in old-fashioned glass over ice cubes. Add a Stick of pineapple.
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Red Swizzle
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glas
# MEASURE: 1/2 oz
# LIQUID:  cherry  flavored brandy
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  orgeat or almond syrup
# MEASURE FLOAT: 0.5
# MEASURE: 2 oz
# LIQUID:  each orange juice and sweet sherry
# MEASURE FLOAT: 2.0
# MEASURE: 2 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 2.0
# MEASURE: 1/2 oz
# LIQUID:  maple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  orange bitters (if desired)
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Strawberry Sunries
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Shake with ice and strain into chilled sour glass. Garnish with lime.
# ----------------------
# COCKTAIL NAME: Ko Adang
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Pour lime vodka over ice cubes in a collins glass. Fill with ice. Add brandy and peach-flavored brandy. Stir and garnish with additional mint.
# MEASURE: fill
# LIQUID NAME: lemon-lime soda
# MEASURE FLOAT: 0.0
# ----------------------
# COCKTAIL NAME: Gimlet
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir first three ingredients in ice-filled highball glass. Stir. Squeeze and add lemon. Garnish with orange and cherry.
# MEASURE: fill
# LIQUID NAME: ginger ale or soda water
# MEASURE FLOAT: 0.0
# ----------------------
# COCKTAIL NAME: Vodka Cooler
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 3 oz
# LIQUID:  fresh orange juice
# MEASURE FLOAT: 3.0
# MEASURE: 1 oz
# LIQUID:  each orange juice and sweet sherry
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  anisette
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Bucks Fizz
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Fill Collins glass 1/2 full with crushed ice. Garnish with pineapple and orange slices, and a cherry.
# MEASURE: 3/4 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.75
# MEASURE: 1/4 oz
# LIQUID:  mezcal
# MEASURE FLOAT: 0.25
# MEASURE: 2 oz
# LIQUID:  ginger beer
# MEASURE FLOAT: 2.0
# ----------------------
# COCKTAIL NAME: Gilroy Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Muddle oranges and pineapple and strawberries.
# MEASURE: 1/2 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Gaugin
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Garnish with mint sprig.
# MEASURE: 1 1/2 oz
# LIQUID:  madeira
# MEASURE FLOAT: 1.5
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# MEASURE: 2 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 2.0
# ----------------------
# COCKTAIL NAME: Devil's Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1 oz
# LIQUID:  claret
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  each orange juice and sweet sherry
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  grenadine
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Chateau Briand's Rum Cow
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 6 oz
# LIQUID:  whiskey barrel bitters
# MEASURE FLOAT: 6.0
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Canadian Pineapple
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake and strain into ice-filled highball glass. Top with soda water. Garnish with strawberry and basil.
# MEASURE: 1/2 oz
# LIQUID:  sakd rum
# MEASURE FLOAT: 0.5
# MEASURE: 3/4 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 0.75
# MEASURE: 3/4 oz
# LIQUID:  benedictine
# MEASURE FLOAT: 0.75
# MEASURE: 1/2 oz
# LIQUID:  white creme de cacao
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  chile syrup
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: American Trilogy
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: serve with an olive.
# MEASURE: 3/4 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.75
# ----------------------
# COCKTAIL NAME: Bourbon And Elder
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Rim chilled old-fashioned glass with lemon and sugar. Stir remaining ingredients with ice in hursing died frngeb of glass and serve i
# MEASURE: 1 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Orange Gin Rickey
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1 1/2 oz
# LIQUID:  gin & ginger ale
# MEASURE FLOAT: 1.5
# MEASURE: 2 oz
# LIQUID:  dark rum
# MEASURE FLOAT: 2.0
# MEASURE: 1/2 oz
# LIQUID:  coffee liqueur
# MEASURE FLOAT: 0.5
# MEASURE: 1/4 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.25
# ----------------------
# COCKTAIL NAME: Thoet Margari
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1 1/2 oz
# LIQUID:  blanco tequila
# MEASURE FLOAT: 1.5
# MEASURE: 1 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 1.0
# MEASURE: 1/2 oz
# LIQUID:  crema di limoncello
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Harvard Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 3/4 oz
# LIQUID:  ligitirt
# MEASURE FLOAT: 0.75
# MEASURE: 3/4 oz
# LIQUID:  pineapple juice
# MEASURE FLOAT: 0.75
# MEASURE: 2 oz
# LIQUID:  orange bitters (if desired)
# MEASURE FLOAT: 2.0
# ----------------------
# COCKTAIL NAME: Green Dragon Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Pour into highball glass over ice cubes and fill with ginger ale. Stir.
# MEASURE: 2 oz
# LIQUID:  hard cider
# MEASURE FLOAT: 2.0
# MEASURE: fill
# LIQUID NAME: ginger ale or soda water
# MEASURE FLOAT: -1.0
# ----------------------
# COCKTAIL NAME: Clamato Cocktail
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Shake rum, pineapple juice, and syrup with ice and strain into chilled highball glass over 2 ice cubes. Fill with ginger ale or soda water and stir. Add
# MEASURE: 3/4 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.75
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# MEASURE: fill
# LIQUID NAME: ginger ale or soda water
# MEASURE FLOAT: -0.875
# ----------------------
# COCKTAIL NAME: Shady Lady
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Muddle basil liqueur. Garnish with strawberry and 4 peach slice of lime in glass.
# MEASURE: 3/4 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 0.75
# MEASURE: 1 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Brandy Alexander
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into chilled cocktail glass. Add orange twist.
# MEASURE: 1/4 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 0.25
# MEASURE: 1 oz
# LIQUID:  green chartreuse
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Coffee Old-Fashioned
# GLASS NAME: Old-Fashioned Glass
# INSTRUCTIONS: Pour tequila into ice-filled old-fashioned glass. Add orange twist.
# ----------------------
# COCKTAIL NAME: Bull 3grasse
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  green creme de menthe
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Rinah Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Combine ingredients and hot syrug in Collins glass. Add crushed ice and port.
# MEASURE: 3/4 oz
# LIQUID:  half-and-half
# MEASURE FLOAT: 0.75
# MEASURE: 1 oz
# LIQUID:  blue curacao
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Cuban Cocktail No. 2
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add bitters and lemon twist.
# MEASURE: 1 oz
# LIQUID:  each orange juice and sweet sherry
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Tiger Tanaka
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass. Add a twist of orange peel.
# MEASURE: 3/4 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.75
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Margarita
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass. Serve with an olive.
# MEASURE: 1/2 oz
# LIQUID:  mezcal
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  yellow chartreuse
# MEASURE FLOAT: 0.5
# MEASURE: 1/4 oz
# LIQUID:  fernet-branca
# MEASURE FLOAT: 0.25
# ----------------------
# COCKTAIL NAME: Victory Collins
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 2 oz
# LIQUID:  white creme de cacao
# MEASURE FLOAT: 2.0
# MEASURE: 1 oz
# LIQUID:  light cream (if desired)
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Casa Blanca
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 2 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 2.0
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  sugar syrup
# MEASURE FLOAT: 1.0
# MEASURE: M 1/4 oz
# LIQUID:  each orange juice and sweet sherry
# MEASURE FLOAT: 1.0
# MEASURE: 2 oz
# LIQUID:  light cream (if desired)
# MEASURE FLOAT: 2.0
# ----------------------
# COCKTAIL NAME: Bloodhound Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Catalina Margarita
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into highball glass over two ice cubes. Fill with carbonated water and stir.
# MEASURE: 1/2 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 0.5
# MEASURE: 1/4 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.25
# ----------------------
# COCKTAIL NAME: Spanish Town Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Royal Cocktail
# GLASS NAME: Sour Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass. Float an unbroken egg yolk on top
# MEASURE: 1 oz
# LIQUID:  ginger ale or soda water
# MEASURE FLOAT: 1.0
# MEASURE: 2 oz
# LIQUID:  lime vodka
# MEASURE FLOAT: 2.0
# MEASURE: 1 oz
# LIQUID:  pineapple juice
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Thanksgiving Special Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass.
# MEASURE: 2 oz
# LIQUID:  apricot flavored brandy
# MEASURE FLOAT: 2.0
# ----------------------
# COCKTAIL NAME: Cool Carlos
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass.
# MEASURE: 3/4 oz
# LIQUID:  dubonnet
# MEASURE FLOAT: 0.75
# ----------------------
# COCKTAIL NAME: Santrick Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass. Serve with a cherry.
# MEASURE: 1 oz
# LIQUID:  creme de cacao (white)
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  light cream (if desired)
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Delmonico No. 2
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Add lemon twist.
# MEASURE: 1/3 oz
# LIQUID:  triple sec
# MEASURE FLOAT: 0.3333333333333333
# MEASURE: 1/2 oz
# LIQUID:  rose's lime juice
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Shady Lady
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Stir with ice and strain into chilled cocktail glass. Garnish with mint.
# MEASURE: 1 oz
# LIQUID:  angostura bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: High Cotton
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass.
# MEASURE: fill
# LIQUID NAME: carbonated water
# MEASURE FLOAT: 0.0
# ----------------------
# COCKTAIL NAME: Free Silver
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Shake with ice and strain into chilled champagne flute. Garnish with flower.
# MEASURE: 1/2 oz
# LIQUID:  sweet vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1/2 oz
# LIQUID:  anisette
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Alexander Cocktail No. 1
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  maraschino liqueur
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Kup's Indispensable Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with cracked ice and strain into cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  dry vermouth
# MEASURE FLOAT: 0.5
# MEASURE: 1 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.0
# MEASURE: 1 oz
# LIQUID:  whiskey barrel bitters
# MEASURE FLOAT: 1.0
# ----------------------
# COCKTAIL NAME: Thunder
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into chilled cocktail glass.
# MEASURE: 1/2 oz
# LIQUID:  coffee liqueur
# MEASURE FLOAT: 0.5
# ----------------------
# COCKTAIL NAME: Americana
# GLASS NAME: Collins Glass
# INSTRUCTIONS: Add first baridd in an old-fashioned glass. Add ice and stir again. Garnish with licorice.
# MEASURE: 1/2 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.5
# MEASURE: 1/4 oz
# LIQUID:  mezcal
# MEASURE FLOAT: 0.25
# MEASURE: 2 oz
# LIQUID:  ginger beer
# MEASURE FLOAT: 2.0
# ----------------------
# COCKTAIL NAME: Pollyanna Cocktail
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Stir with ice and strain into cocktail glass. Serve with a cherry.
# MEASURE: 1 1/2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 1.5
# ----------------------
# COCKTAIL NAME: May Blosson Fizz
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Shake first four ingredients with ice and strain into a collins glass and add lime juice to tar. Add ginger in mixing glass. Add remaining ingredients. Shake with ice. Double-strain into ice-fi
# MEASURE: 1/2 oz
# LIQUID:  fresh lemon juice
# MEASURE FLOAT: 0.5
# MEASURE: fill
# LIQUID NAME: chilled champagne
# MEASURE FLOAT: -0.25
# ----------------------
# COCKTAIL NAME: Mexicana
# GLASS NAME: Cocktail Glass
# INSTRUCTIONS: Shake with ice and strain into chilled cocktail glass. Garnish with mint.
# MEASURE: 1/2 oz
# LIQUID:  fresh lime juice
# MEASURE FLOAT: 0.5
# MEASURE: 1/4 oz
# LIQUID:  simple syrup
# MEASURE FLOAT: 0.25
# ----------------------
# COCKTAIL NAME: Ruby Fizz
# GLASS NAME: Highball Glass
# INSTRUCTIONS: Shake with ice and strain into cocktail glass. Add a twist of lemon peel.
# MEASURE: 1 oz
# LIQUID:  light cream (if desired)
# MEASURE FLOAT: 1.0
# MEASURE: 2 oz
# LIQUID:  orange flavored gin
# MEASURE FLOAT: 2.0
# ----------------------
# ####################################

# %%
good_cocktails
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-a46f12707966> in <module>
# ----> 1 good_cocktails
#
# NameError: name 'good_cocktails' is not defined

# %%
count = 0
for recipe in all_recipes:
    while count < 1:
        if recipe['Category'] == 'AI Instant Classic':
            print(recipe)
            count += 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-fd2e55a68331> in <module>
#       2 for recipe in all_recipes:
#       3     while count < 1:
# ----> 4         if recipe['Category'] == 'AI Instant Classic':
#       5             print(recipe)
#       6             count += 1
#
# KeyboardInterrupt:

# %%
for liquid in liquid_list:
    if liquid not in liquids:
        #generate random hex color
        hex_color = "#{:06x}".format(random.randint(0, 0xFFFFFF))
        #insert new liquid and color into liquids table
        sql = f'INSERT INTO Liquids (Liquid_Name, Color) VALUES ("{liquid}", "{hex_color}");'
        cursor.execute(sql)
        conn.commit()
        print("New Liquid Added to Liquids Table")

# %%
len(all_recipes)
# Out:
# 976
